# %% [markdown]
# <a href="https://colab.research.google.com/github/yaqob-M-almateri/cloud-computing2/blob/main/yaqobalmateri22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("yaqob almateri")
# Out:
# yaqob almateri

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
